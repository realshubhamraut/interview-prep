# %%
# %%html
# <link href="https://fonts.googleapis.com/css2?family=Source+Serif+4:wght@300;400;500;600;700&display=swap" rel="stylesheet">
#
# <style>
# /* markdown + output */
# body, .markdown-body, .jp-RenderedHTMLCommon, div.text_cell_render,
# .notebook, .notebook * {
#   font-family: "Source Serif 4", serif !important;
# }
#
# /* code editor (monaco) */
# .monaco-editor, .monaco-editor * {
#   font-family: "Source Serif 4", serif !important;
# }
# </style>
# Out:
# <link href="https://fonts.googleapis.com/css2?family=Source+Serif+4:wght@300;400;500;600;700&display=swap" rel="stylesheet">
#
# <style>
# /* markdown + output */
# body, .markdown-body, .jp-RenderedHTMLCommon, div.text_cell_render,
# .notebook, .notebook * {
#   font-family: "Source Serif 4", serif !important;
# }
#
# /* code editor (monaco) */
# .monaco-editor, .monaco-editor * {
#   font-family: "Source Serif 4", serif !important;
# }
# </style>

# %% [markdown]
# #### **Pandas Cheat Sheet — Most Used Functions**
#
# ####  Basic inspection
# | Function | Purpose |
# |---------|---------|
# | df.head() | Show first rows |
# | df.tail() | Show last rows |
# | df.info() | Summary: datatypes + null counts |
# | df.describe() | Numerical summary (mean, std, etc.) |
# | df.shape | (rows, columns) |
# | df.columns | List of column names |
# | df.dtypes | Datatype of each column |
# | df.index | Show index range |
#
# ---
#
# ####  Handling missing values
# | Function | Purpose |
# |---------|---------|
# | df.isnull() | True/False for missing |
# | df.isnull().sum() | Count missing values |
# | df.dropna() | Remove rows with missing values |
# | df.fillna(value) | Fill missing values |
#
# ---
#
# ####  Selecting & filtering
# | Function | Purpose |
# |---------|---------|
# | df['col'] | Select column |
# | df[['col1','col2']] | Select multiple columns |
# | df.loc[row_label, col_label] | Select by label |
# | df.iloc[row_index, col_index] | Select by index |
# | df[df.col > 10] | Conditional filtering |
# | df.query("col > 10") | SQL-like filtering |
#
# ---
#
# ####  Sorting
# | Function | Purpose |
# |---------|---------|
# | df.sort_values('col') | Sort by column |
# | df.sort_values(['col1', 'col2']) | Sort by multiple columns |
#
# ---
#
# ####  Handling duplicates
# | Function | Purpose |
# |---------|---------|
# | df.duplicated() | Identify duplicates |
# | df.drop_duplicates() | Remove duplicates |
#
# ---
#
# ####  Renaming & modifying columns
# | Function | Purpose |
# |---------|---------|
# | df.rename(columns={'old':'new'}) | Rename columns |
# | df.astype({'col':'int'}) | Change datatype |
# | df.drop(columns=['col']) | Drop a column |
#
# ---
#
# ####  Combining data
# | Function | Purpose |
# |---------|---------|
# | pd.concat([df1, df2]) | Vertical/Horizontal stacking |
# | df.merge(df2, on='col') | SQL-style join |
# | df.join(df2) | Join by index |
#
# ---
#
# ####  GroupBy & Aggregation
# | Function | Purpose |
# |---------|---------|
# | df.groupby('col').mean() | Group & compute mean |
# | df.groupby('col').agg(['mean','sum','count']) | Multi aggregation |
# | df.groupby(['A','B']).size() | Count rows per group |
#
# ---
#
# ####  Value counts & unique
# | Function | Purpose |
# |---------|---------|
# | df.col.value_counts() | Count of each category |
# | df.col.nunique() | Number of unique values |
# | df.col.unique() | List of unique values |
#
# ---
#
# ####  Pivoting
# | Function | Purpose |
# |---------|---------|
# | df.pivot(index='A', columns='B', values='C') | Reshape table |
# | df.pivot_table(index='A', columns='B', values='C', aggfunc='sum') | Pivot with aggregation |
#
# ---
#
# ####  Statistics (EDA)
# | Function | Purpose |
# |---------|---------|
# | df.col.mean() | Mean |
# | df.col.median() | Median |
# | df.col.mode() | Mode |
# | df.col.std() | Standard deviation |
# | df.col.var() | Variance |
# | df.col.min(), df.col.max() | Range |
# | df.corr() | Correlation matrix |
# | df.cov() | Covariance matrix |
#
# ---

# %%
import pandas as pd
import os
import numpy as np

# %%
os.chdir(r'/Users/proxim/Desktop/CDAC-DBDA-coursework/08.advanced-analytics-stats')

# %%
s1 = pd.Series([4,7,6,8,9])

# %%
s1
# Out:
# 0    4
# 1    7
# 2    6
# 3    8
# 4    9
# dtype: int64

# %%
s1[2]
# Out:
# np.int64(6)

# %%
s1[1:4]
# Out:
# 1    7
# 2    6
# 3    8
# dtype: int64

# %%
s1 = pd.Series([4,7,6,8,9], index = ['A','B','C','D','E'])

# %%
s1
# Out:
# A    4
# B    7
# C    6
# D    8
# E    9
# dtype: int64

# %%
s1.iloc[2] # extracting from inbuild index =  index reference, [note - we can also pass the loc reference in iloc]
# Out:
# np.int64(6)

# %%
s1.loc['C'] # extracting from custom index = label reference which is custom


# also the custom labes could be duplicate such as index = ['A','B','A','B']
# Out:
# np.int64(6)

# %%
s1.iloc[[1,3]]
# Out:
# B    7
# D    8
# dtype: int64

# %%
s2 = s1.iloc[[1,3]]

# %%
s2
# Out:
# B    7
# D    8
# dtype: int64

# %%
# we can also make the custom index and custom elements with the help of dictionary

# %%
d1 = {'A':2, 'B':7,'C':8}

# %%
d1
# Out:
# {'A': 2, 'B': 7, 'C': 8}

# %%
s2 = pd.Series(d1)

# %%
s2
# Out:
# A    2
# B    7
# C    8
# dtype: int64

# %%
s3 = pd.Series([5,3], index = ['D','E'])

# %%
s3
# Out:
# D    5
# E    3
# dtype: int64

# %%
s2 = pd.concat([s2,s3])

# %%
s2
# Out:
# A    2
# B    7
# C    8
# D    5
# E    3
# dtype: int64

# %%
s3
# Out:
# D    5
# E    3
# dtype: int64

# %%
s2.loc['B'] = 17

# %%
s2
# Out:
# A     2
# B    17
# C     8
# D     5
# E     3
# dtype: int64

# %%
s2.drop(s2.index[2])
# Out:
# A     2
# B    17
# D     5
# E     3
# dtype: int64

# %%
s2.drop('C')
# Out:
# A     2
# B    17
# D     5
# E     3
# dtype: int64

# %%
df = pd.DataFrame([['A',25,76], ['B',45, 90], ['C',26,58]], columns = ['Name', 'RollNo', 'Marks'])

# %%
df
# Out:
#   Name  RollNo  Marks
# 0    A      25     76
# 1    B      45     90
# 2    C      26     58

# %%
d1 = {'PlayerName' :['Sachin', 'Dhoni', 'Gill', 'Surya'], 'Team':['MI','CSK', 'GT','MI']}

# %%
d1
# Out:
# {'PlayerName': ['Sachin', 'Dhoni', 'Gill', 'Surya'],
#  'Team': ['MI', 'CSK', 'GT', 'MI']}

# %%
newdf = pd.DataFrame([['H',25, 68], ['R',26, 45]], columns=['XYZ','LMQ', 'PQR'])

# %%
newdf
# Out:
#   XYZ  LMQ  PQR
# 0   H   25   68
# 1   R   26   45

# %%
df = pd.concat([df, newdf])

# %%
newdf
# Out:
#   XYZ  LMQ  PQR
# 0   H   25   68
# 1   R   26   45

# %%
df.iloc[[1,3]]
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR
# 1    B    45.0   90.0  NaN   NaN   NaN
# 0  NaN     NaN    NaN    H  25.0  68.0

# %%
df2 = pd.concat([df, newdf]).reset_index(drop=True)

# %%
df2
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR
# 0    A    25.0   76.0  NaN   NaN   NaN
# 1    B    45.0   90.0  NaN   NaN   NaN
# 2    C    26.0   58.0  NaN   NaN   NaN
# 3  NaN     NaN    NaN    H  25.0  68.0
# 4  NaN     NaN    NaN    R  26.0  45.0
# 5  NaN     NaN    NaN    H  25.0  68.0
# 6  NaN     NaN    NaN    R  26.0  45.0

# %%
df2 = pd.concat([df, newdf]).reset_index()  # add back index

# %%
df2
# Out:
#    index Name  RollNo  Marks  XYZ   LMQ   PQR
# 0      0    A    25.0   76.0  NaN   NaN   NaN
# 1      1    B    45.0   90.0  NaN   NaN   NaN
# 2      2    C    26.0   58.0  NaN   NaN   NaN
# 3      0  NaN     NaN    NaN    H  25.0  68.0
# 4      1  NaN     NaN    NaN    R  26.0  45.0
# 5      0  NaN     NaN    NaN    H  25.0  68.0
# 6      1  NaN     NaN    NaN    R  26.0  45.0

# %%
x1 = [45,68,76,89,2,34,1]

# %%
df2['marks2'] = x1

# %%
df2
# Out:
#    index Name  RollNo  Marks  XYZ   LMQ   PQR  marks2
# 0      0    A    25.0   76.0  NaN   NaN   NaN      45
# 1      1    B    45.0   90.0  NaN   NaN   NaN      68
# 2      2    C    26.0   58.0  NaN   NaN   NaN      76
# 3      0  NaN     NaN    NaN    H  25.0  68.0      89
# 4      1  NaN     NaN    NaN    R  26.0  45.0       2
# 5      0  NaN     NaN    NaN    H  25.0  68.0      34
# 6      1  NaN     NaN    NaN    R  26.0  45.0       1

# %%
df2.drop([0,2])
# Out:
#    index Name  RollNo  Marks  XYZ   LMQ   PQR  marks2
# 1      1    B    45.0   90.0  NaN   NaN   NaN      68
# 3      0  NaN     NaN    NaN    H  25.0  68.0      89
# 4      1  NaN     NaN    NaN    R  26.0  45.0       2
# 5      0  NaN     NaN    NaN    H  25.0  68.0      34
# 6      1  NaN     NaN    NaN    R  26.0  45.0       1

# %%
df2
# Out:
#    index Name  RollNo  Marks  XYZ   LMQ   PQR  marks2
# 0      0    A    25.0   76.0  NaN   NaN   NaN      45
# 1      1    B    45.0   90.0  NaN   NaN   NaN      68
# 2      2    C    26.0   58.0  NaN   NaN   NaN      76
# 3      0  NaN     NaN    NaN    H  25.0  68.0      89
# 4      1  NaN     NaN    NaN    R  26.0  45.0       2
# 5      0  NaN     NaN    NaN    H  25.0  68.0      34
# 6      1  NaN     NaN    NaN    R  26.0  45.0       1

# %%
df2 = df2.drop('index', axis=1)

# %%
df2
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR  marks2
# 0    A    25.0   76.0  NaN   NaN   NaN      45
# 1    B    45.0   90.0  NaN   NaN   NaN      68
# 2    C    26.0   58.0  NaN   NaN   NaN      76
# 3  NaN     NaN    NaN    H  25.0  68.0      89
# 4  NaN     NaN    NaN    R  26.0  45.0       2
# 5  NaN     NaN    NaN    H  25.0  68.0      34
# 6  NaN     NaN    NaN    R  26.0  45.0       1

# %%
df2.drop(df2.columns[1], axis =1 )
# Out:
#   Name  Marks  XYZ   LMQ   PQR  marks2
# 0    A   76.0  NaN   NaN   NaN      45
# 1    B   90.0  NaN   NaN   NaN      68
# 2    C   58.0  NaN   NaN   NaN      76
# 3  NaN    NaN    H  25.0  68.0      89
# 4  NaN    NaN    R  26.0  45.0       2
# 5  NaN    NaN    H  25.0  68.0      34
# 6  NaN    NaN    R  26.0  45.0       1

# %%
df2.iat[1,2] = 60

# %%
df2
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR  marks2
# 0    A    25.0   76.0  NaN   NaN   NaN      45
# 1    B    45.0   60.0  NaN   NaN   NaN      68
# 2    C    26.0   58.0  NaN   NaN   NaN      76
# 3  NaN     NaN    NaN    H  25.0  68.0      89
# 4  NaN     NaN    NaN    R  26.0  45.0       2
# 5  NaN     NaN    NaN    H  25.0  68.0      34
# 6  NaN     NaN    NaN    R  26.0  45.0       1

# %%
df2.at[2,'Marks'] = 68

# %%
df2
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR  marks2
# 0    A    25.0   76.0  NaN   NaN   NaN      45
# 1    B    45.0   60.0  NaN   NaN   NaN      68
# 2    C    26.0   68.0  NaN   NaN   NaN      76
# 3  NaN     NaN    NaN    H  25.0  68.0      89
# 4  NaN     NaN    NaN    R  26.0  45.0       2
# 5  NaN     NaN    NaN    H  25.0  68.0      34
# 6  NaN     NaN    NaN    R  26.0  45.0       1

# %%
erp = pd.read_excel('data/CDAC_DataBook.xlsx', sheet_name='ERPData', engine='openpyxl')

# %%
df.head()
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR
# 0    A    25.0   76.0  NaN   NaN   NaN
# 1    B    45.0   90.0  NaN   NaN   NaN
# 2    C    26.0   58.0  NaN   NaN   NaN
# 0  NaN     NaN    NaN    H  25.0  68.0
# 1  NaN     NaN    NaN    R  26.0  45.0

# %%
df.shape
# Out:
# (5, 6)

# %%
df.tail()
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR
# 0    A    25.0   76.0  NaN   NaN   NaN
# 1    B    45.0   90.0  NaN   NaN   NaN
# 2    C    26.0   58.0  NaN   NaN   NaN
# 0  NaN     NaN    NaN    H  25.0  68.0
# 1  NaN     NaN    NaN    R  26.0  45.0

# %%
df.columns
# Out:
# Index(['Name', 'RollNo', 'Marks', 'XYZ', 'LMQ', 'PQR'], dtype='object')

# %%
list(df.columns)
# Out:
# ['Name', 'RollNo', 'Marks', 'XYZ', 'LMQ', 'PQR']

# %%
df.head()
# Out:
#   Name  RollNo  Marks  XYZ   LMQ   PQR
# 0    A    25.0   76.0  NaN   NaN   NaN
# 1    B    45.0   90.0  NaN   NaN   NaN
# 2    C    26.0   58.0  NaN   NaN   NaN
# 0  NaN     NaN    NaN    H  25.0  68.0
# 1  NaN     NaN    NaN    R  26.0  45.0

# %%
df.columns.values[1] = 'Location'

# %%
erp.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
ind = np.where(erp.Location == 'MWH-2')

# %%
ind
# Out:
# (array([ 2,  7,  8, 15, 35, 36, 42, 45, 46]),)

# %%
df1 = erp.iloc[ind]

# %%
df1
# Out:
#    MaterialID Location  Quantity
# 2     LXCV-21    MWH-2        27
# 7     TMI-43T    MWH-2        29
# 8     GCVB-79    MWH-2        10
# 15    GCVB-79    MWH-2        87
# 35    GCVB-79    MWH-2        31
# 36    GCVB-79    MWH-2        28
# 42    SDRT-67    MWH-2        31
# 45    DDBN-89    MWH-2        69
# 46    AXCP-78    MWH-2        85

# %%
ind = np.where(((erp.Location == 'MWH-2') | (erp.Location == 'MWH-4')) & (erp.Quantity >75))

# %%
ind
# Out:
# (array([ 5, 12, 15, 46]),)

# %%
ind = np.where((erp.Location.isin(['MWH-2', 'MWH-4'])) & (erp.Quantity > 75))

# %%
df2 = erp.iloc[ind].reset_index(drop= True)

# %%
df2
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        78
# 1    TMI-43T    MWH-4        76
# 2    GCVB-79    MWH-2        87
# 3    AXCP-78    MWH-2        85

# %%
min(erp.Quantity)
# Out:
# 10

# %%
ind = np.where(erp.Quantity<=40)

# %%
ind[0]
# Out:
# array([ 0,  2,  4,  6,  7,  8, 10, 13, 16, 18, 20, 28, 30, 34, 35, 36, 40,
#        42, 43, 47, 49])

# %%
df1 = erp.drop(ind[0])

# %%
min(df1.Quantity)
# Out:
# 42

# %%
max(df1.Quantity)
# Out:
# 152

# %%
df = pd.read_excel('data/CDAC_DataBook.xlsx', sheet_name='Pune', engine='openpyxl')

# %%
df.head()
# Out:
#       Name      Subject Grade
# 0   Rakesh       Python     A
# 1    Manoj     MLPython     C
# 2  Vaibhav   Statistics     B
# 3   Hitesh   CommSkills     A
# 4   Suyash  ProjectMgmt     B

# %%
loc = df.where((df.Subject == 'Python') | (df.Subject == 'MLPython'))

# %%
# `ind` is a tuple returned by np.where, use the first element (array of row indices)
rows = ind[0]
erp.iloc[rows]
# Out:
#    MaterialID Location  Quantity
# 0     TMI-43T    MWH-4        34
# 2     LXCV-21    MWH-2        27
# 4     AXCP-78    MWH-4        36
# 6     TMI-43T    MWH-4        31
# 7     TMI-43T    MWH-2        29
# 8     GCVB-79    MWH-2        10
# 10    SDRT-67    MWH-1        34
# 13    TMI-43T    MWH-4        32
# 16    SDRT-67    MWH-5        12
# 18    TMI-43T    MWH-4        34
# 20    TMI-43T    MWH-4        39
# 28    LXCV-21    MWH-5        34
# 30    DDBN-89    MWH-4        27
# 34    GCVB-79    MWH-5        26
# 35    GCVB-79    MWH-2        31
# 36    GCVB-79    MWH-2        28
# 40    DDBN-89    MWH-1        34
# 42    SDRT-67    MWH-2        31
# 43    DDBN-89    MWH-3        38
# 47    AXCP-78    MWH-3        29
# 49    DDBN-89    MWH-1        39

# %%
df1 = loc.dropna(how='all').reset_index(drop=True)

# %%
df1
# Out:
#      Name   Subject Grade
# 0  Rakesh    Python     A
# 1   Manoj  MLPython     C

# %%
erp.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
min_q = erp.Quantity.min()
ind = np.where(erp.Quantity == min_q)

# %%
ind
# Out:
# (array([8]),)

# %%
# `ind` is a tuple returned by np.where, e.g. (array([8]),)
# use the first element (array of row indices) with iloc.
rows = ind[0]

# If you want all matching rows' first column:
df1 = erp.iloc[rows, 0]

# If you want only the first matching value (scalar), uncomment:
# df1 = erp.iloc[rows[0], 0]

# %%
df1
# Out:
# 8    GCVB-79
# Name: MaterialID, dtype: object

# %%
erp
# Out:
#    MaterialID Location  Quantity
# 0     TMI-43T    MWH-4        34
# 1     AXCP-78    MWH-1        67
# 2     LXCV-21    MWH-2        27
# 3     AXCP-78    MWH-5        65
# 4     AXCP-78    MWH-4        36
# 5     TMI-43T    MWH-4        78
# 6     TMI-43T    MWH-4        31
# 7     TMI-43T    MWH-2        29
# 8     GCVB-79    MWH-2        10
# 9     TMI-43T    MWH-1       120
# 10    SDRT-67    MWH-1        34
# 11    SDRT-67    MWH-4        58
# 12    TMI-43T    MWH-4        76
# 13    TMI-43T    MWH-4        32
# 14    TMI-43T    MWH-3        65
# 15    GCVB-79    MWH-2        87
# 16    SDRT-67    MWH-5        12
# 17    SDRT-67    MWH-5       102
# 18    TMI-43T    MWH-4        34
# 19    TMI-43T    MWH-4        52
# 20    TMI-43T    MWH-4        39
# 21    TMI-43T    MWH-4        75
# 22    DDBN-89    MWH-4        48
# 23    DDBN-89    MWH-5        71
# 24    AXCP-78    MWH-1       152
# 25    AXCP-78    MWH-1       109
# 26    DDBN-89    MWH-1        57
# ...

# %%
ind = np.where(erp.Quantity==min(erp.Quantity))

# %%
import pandas as pd

# %%
df = pd.read_excel('data/CDAC_DataBook.xlsx', sheet_name='EmpInfo')

# %%
import pandas as pd
import numpy as np

# %%
df.head(7)
# Out:
#       Name EmpID    Deptt  Passport
# 0   Sudeep  A342  Quality  DF453278
# 1  Ruchika  C578    Sales  CA567657
# 2      NaN  J436    Admin  DF453278
# 3    Arjun  A342      NaN  RF453432
# 4    Rishi  R475    Prodn  DF453278
# 5   Chetan   NaN      NaN  ER534867
# 6   Deepak   NaN  Quality  RF453432

# %%
ind = np.where(df.Deptt.isnull())

# %%
ind
# Out:
# (array([3, 5]),)

# %%
ind2 = np.where((df.EmpID.isnull()| df.Deptt.isnull()))

# %%
ind2
# Out:
# (array([3, 5, 6]),)

# %%
df1 = df.iloc[ind2[0]]

# %%
df1
# Out:
#      Name EmpID    Deptt  Passport
# 3   Arjun  A342      NaN  RF453432
# 5  Chetan   NaN      NaN  ER534867
# 6  Deepak   NaN  Quality  RF453432

# %%
ind2 = not(np.where(df.EmpID.isnull()))

# where empid is not null

# %%
ind2
# Out:
# False

# %%
newdf = df.dropna()

# %%
newdf
# Out:
#       Name EmpID    Deptt  Passport
# 0   Sudeep  A342  Quality  DF453278
# 1  Ruchika  C578    Sales  CA567657
# 4    Rishi  R475    Prodn  DF453278

# %%
df.isnull().sum()
# Out:
# Name        1
# EmpID       2
# Deptt       2
# Passport    0
# dtype: int64

# %%
df.Deptt.fillna('Overhead')
# Out:
# 0     Quality
# 1       Sales
# 2       Admin
# 3    Overhead
# 4       Prodn
# 5    Overhead
# 6     Quality
# Name: Deptt, dtype: object

# %%
df
# Out:
#       Name EmpID    Deptt  Passport
# 0   Sudeep  A342  Quality  DF453278
# 1  Ruchika  C578    Sales  CA567657
# 2      NaN  J436    Admin  DF453278
# 3    Arjun  A342      NaN  RF453432
# 4    Rishi  R475    Prodn  DF453278
# 5   Chetan   NaN      NaN  ER534867
# 6   Deepak   NaN  Quality  RF453432

# %%
df['New Col'] = df.Deptt.fillna('Overhead')

# %%
df.Deptt.fillna('Overhead', inplace = True)
# Out:
# /var/folders/57/62f2rv1j4w94h8tfp_c43b1c0000gn/T/ipykernel_65633/969436898.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Deptt.fillna('Overhead', inplace = True)

# %%
# in case of numeric column, nan is median values for that column

# %%
x1 = np.array([1,2,3,np.nan,5,np.nan,7])

# %%
df['Marks'] = x1

# %%
df
# Out:
#       Name EmpID     Deptt  Passport   New Col  Marks
# 0   Sudeep  A342   Quality  DF453278   Quality    1.0
# 1  Ruchika  C578     Sales  CA567657     Sales    2.0
# 2      NaN  J436     Admin  DF453278     Admin    3.0
# 3    Arjun  A342  Overhead  RF453432  Overhead    NaN
# 4    Rishi  R475     Prodn  DF453278     Prodn    5.0
# 5   Chetan   NaN  Overhead  ER534867  Overhead    NaN
# 6   Deepak   NaN   Quality  RF453432   Quality    7.0

# %%
df['Marks'] = df.Marks.fillna(df.Marks.median())

# %%
df
# Out:
#       Name EmpID     Deptt  Passport   New Col  Marks
# 0   Sudeep  A342   Quality  DF453278   Quality    1.0
# 1  Ruchika  C578     Sales  CA567657     Sales    2.0
# 2      NaN  J436     Admin  DF453278     Admin    3.0
# 3    Arjun  A342  Overhead  RF453432  Overhead    3.0
# 4    Rishi  R475     Prodn  DF453278     Prodn    5.0
# 5   Chetan   NaN  Overhead  ER534867  Overhead    3.0
# 6   Deepak   NaN   Quality  RF453432   Quality    7.0

# %%
df.Deptt.fillna(method='ffill')
# Out:
# /var/folders/57/62f2rv1j4w94h8tfp_c43b1c0000gn/T/ipykernel_65633/536854854.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.Deptt.fillna(method='ffill')
# 0     Quality
# 1       Sales
# 2       Admin
# 3    Overhead
# 4       Prodn
# 5    Overhead
# 6     Quality
# Name: Deptt, dtype: object

# %%
df['Marks'] = df.Marks.fillna(df.Marks.mode())

# %%
df
# Out:
#       Name EmpID     Deptt  Passport   New Col  Marks
# 0   Sudeep  A342   Quality  DF453278   Quality    1.0
# 1  Ruchika  C578     Sales  CA567657     Sales    2.0
# 2      NaN  J436     Admin  DF453278     Admin    3.0
# 3    Arjun  A342  Overhead  RF453432  Overhead    3.0
# 4    Rishi  R475     Prodn  DF453278     Prodn    5.0
# 5   Chetan   NaN  Overhead  ER534867  Overhead    3.0
# 6   Deepak   NaN   Quality  RF453432   Quality    7.0

# %%
df.head()
# Out:
#       Name EmpID     Deptt  Passport   New Col  Marks
# 0   Sudeep  A342   Quality  DF453278   Quality    1.0
# 1  Ruchika  C578     Sales  CA567657     Sales    2.0
# 2      NaN  J436     Admin  DF453278     Admin    3.0
# 3    Arjun  A342  Overhead  RF453432  Overhead    3.0
# 4    Rishi  R475     Prodn  DF453278     Prodn    5.0

# %%
df
# Out:
#       Name EmpID     Deptt  Passport   New Col  Marks
# 0   Sudeep  A342   Quality  DF453278   Quality    1.0
# 1  Ruchika  C578     Sales  CA567657     Sales    2.0
# 2      NaN  J436     Admin  DF453278     Admin    3.0
# 3    Arjun  A342  Overhead  RF453432  Overhead    3.0
# 4    Rishi  R475     Prodn  DF453278     Prodn    5.0
# 5   Chetan   NaN  Overhead  ER534867  Overhead    3.0
# 6   Deepak   NaN   Quality  RF453432   Quality    7.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df.tail()
# Out:
#      Name EmpID     Deptt  Passport   New Col  Marks
# 2     NaN  J436     Admin  DF453278     Admin    3.0
# 3   Arjun  A342  Overhead  RF453432  Overhead    3.0
# 4   Rishi  R475     Prodn  DF453278     Prodn    5.0
# 5  Chetan   NaN  Overhead  ER534867  Overhead    3.0
# 6  Deepak   NaN   Quality  RF453432   Quality    7.0

# %%
df.duplicated('Passport')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# dtype: bool

# %%
i= np.where(df.duplicated('Passport'))

# %%
i
# Out:
# (array([2, 4, 6]),)

# %%
df = df.iloc[i]

# %%
df
# Out:
#      Name EmpID    Deptt  Passport  New Col  Marks
# 2     NaN  J436    Admin  DF453278    Admin    3.0
# 4   Rishi  R475    Prodn  DF453278    Prodn    5.0
# 6  Deepak   NaN  Quality  RF453432  Quality    7.0

# %%
np.where(df.Passport.duplicated(keep=False))
# Out:
# (array([0, 1]),)

# %%
np.where(df.Passport.duplicated(keep='first')) # except first
# Out:
# (array([1]),)

# %%
np.where(df.Passport.duplicated(keep='last')) # except last
# Out:
# (array([0]),)

# %% [markdown]
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 2 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      2 non-null      object
#  1   EmpID     2 non-null      object
#  2   Deptt     3 non-null      object
#  3   Passport  3 non-null      object
#  4   New Col   3 non-null      object
#  5   Marks     3 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 168.0+ bytes

# %%
df.shape
# Out:
# (3, 6)

# %%
df.columns
# Out:
# Index(['Name', 'EmpID', 'Deptt', 'Passport', 'New Col', 'Marks'], dtype='object')

# %%
df.index
# Out:
# Index([2, 4, 6], dtype='int64')

# %%
df['Name']
# Out:
# 2       NaN
# 4     Rishi
# 6    Deepak
# Name: Name, dtype: object

# %%
df[['Name', 'Marks']]
# Out:
#      Name  Marks
# 2     NaN    3.0
# 4   Rishi    5.0
# 6  Deepak    7.0

# %%
df.iloc[1:5]
# Out:
#      Name EmpID    Deptt  Passport  New Col  Marks
# 4   Rishi  R475    Prodn  DF453278    Prodn    5.0
# 6  Deepak   NaN  Quality  RF453432  Quality    7.0

# %%
df
# Out:
#      Name EmpID    Deptt  Passport  New Col  Marks
# 2     NaN  J436    Admin  DF453278    Admin    3.0
# 4   Rishi  R475    Prodn  DF453278    Prodn    5.0
# 6  Deepak   NaN  Quality  RF453432  Quality    7.0

# %%
df[df['Marks']>1]
# Out:
#      Name EmpID    Deptt  Passport  New Col  Marks
# 2     NaN  J436    Admin  DF453278    Admin    3.0
# 4   Rishi  R475    Prodn  DF453278    Prodn    5.0
# 6  Deepak   NaN  Quality  RF453432  Quality    7.0

# %%
eg = pd.read_excel('data/subject.xlsx')

# %%
eg.Subject.isnull().sum()
# Out:
# np.int64(22)

# %%
eg1=eg.Subject.value_counts().reset_index()

# %%
eg1['prop'] = eg1['count']/sum(eg1['count'])

# %%
eg1['miss'] = np.round(eg1.prop*22)

# %%
ind = np.where(eg.Subject.isnull())

# %%
import random

random.shuffle(ind[0])

random.shuffle(ind[0])

# %%
eg.iloc[ind[0][:11]] = 'Maths'
eg.iloc[ind[0][11:17]] = 'Science'
eg.iloc[ind[0][17:]] = 'Arts'

# %%
eg.head()
# Out:
#    Subject
# 0    Maths
# 1  Science
# 2    Maths
# 3    Maths
# 4    Maths
