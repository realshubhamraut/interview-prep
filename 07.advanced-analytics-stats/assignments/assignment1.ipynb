# %% [markdown]
# In the files SalesData.xlsx, do the following tasks/ actions
#
# 1. Replace the missing values with suitable values
# 2. Check if there are any rows which are duplicate (complete row). Remove if any
# 3. Create a new column with the name TotalPrice which should be a product of Quantity and Unit_Price.
# 4. Create a new column with the name Code. The value in Code column should be A if the TotalPrice is more than 60000. If it is between 10000 and 60000 then the value in Code column should be B. The value should be C if the value in TotalPrice is less then 10000
# 5. Create a subset of the rows where the Code is either A or B. What is the TotalPrice for these rows
# 6. What are the products for which there have been more than 100 enquiries
# 7. Which category has appeared most often in this dataset
# 8. Which category has the largest number of enquiries

# %%
import os
import pandas as pd
import numpy as np

# %%
import os
os.chdir(r'/Users/proxim/Desktop/CDAC-DBDA-coursework/08.advanced-analytics-stats')

# %%
df = pd.read_excel('data/SalesData.xlsx')

# %%
df.head().count(na)
# Out:
#     Product     Category   Zone  Quantity  Unit_Price  Enquiries
# 0    Laptop  Electronics  North        10       55000       24.0
# 1     Mouse  Electronics  South        50         500       54.0
# 2  Keyboard  Electronics  North        20         900       37.0
# 3     Chair    Furniture  North         5        3000        NaN
# 4     Table    Furniture  North         2        7000       68.0

# %%
df.isna().sum()
# Out:
# Product       0
# Category      0
# Zone          6
# Quantity      0
# Unit_Price    0
# Enquiries     0
# dtype: int64

# %%
df['Zone'] = df['Zone'].fillna(df['Zone'].mode())

# %%
df.isna().sum()
# Out:
# Product       0
# Category      0
# Zone          6
# Quantity      0
# Unit_Price    0
# Enquiries     0
# dtype: int64
